# %%
emails=open(r"fradulent_emails.txt",'r').read()

# %%
print(emails[:100])
# Out:
# From r  Wed Oct 30 21:41:56 2002
# Return-Path: <james_ngola2002@maktoob.com>
# X-Sieve: cmu-sieve 2.0
# R

# %%
emails[:1000]
# Out:
# 'From r  Wed Oct 30 21:41:56 2002\nReturn-Path: <james_ngola2002@maktoob.com>\nX-Sieve: cmu-sieve 2.0\nReturn-Path: <james_ngola2002@maktoob.com>\nMessage-Id: <200210310241.g9V2fNm6028281@cs.CU>\nFrom: "MR. JAMES NGOLA." <james_ngola2002@maktoob.com>\nReply-To: james_ngola2002@maktoob.com\nTo: webmaster@aclweb.org\nDate: Thu, 31 Oct 2002 02:38:20 +0000\nSubject: URGENT BUSINESS ASSISTANCE AND PARTNERSHIP\nX-Mailer: Microsoft Outlook Express 5.00.2919.6900 DM\nMIME-Version: 1.0\nContent-Type: text/plain; charset="us-ascii"\nContent-Transfer-Encoding: 8bit\nX-MIME-Autoconverted: from quoted-printable to 8bit by sideshowmel.si.UM id g9V2foW24311\nStatus: O\n\nFROM:MR. JAMES NGOLA.\nCONFIDENTIAL TEL: 233-27-587908.\nE-MAIL: (james_ngola2002@maktoob.com).\n\nURGENT BUSINESS ASSISTANCE AND PARTNERSHIP.\n\n\nDEAR FRIEND,\n\nI AM ( DR.) JAMES NGOLA, THE PERSONAL ASSISTANCE TO THE LATE CONGOLESE (PRESIDENT LAURENT KABILA) WHO WAS ASSASSINATED BY HIS BODY GUARD ON 16TH JAN. 2001.\n\n\nTHE INCI
# ...

# %%
import re

# %%
for line in re.findall("From:.*",emails):
    print(line)
# Out:
# From: "MR. JAMES NGOLA." <james_ngola2002@maktoob.com>
# From: "Mr. Ben Suleman" <bensul2004nng@spinfinder.com>
# From: "PRINCE OBONG ELEME" <obong_715@epatra.com>
# From: "PRINCE OBONG ELEME" <obong_715@epatra.com>
# From: "Maryam Abacha" <m_abacha03@www.com>
# From: Kuta David <davidkuta@postmark.net>
# From: "Barrister tunde dosumu" <tunde_dosumu@lycos.com>
# From: "William Drallo" <william2244drallo@maktoob.com>
# From: "MR USMAN ABDUL" <abdul_817@rediffmail.com>
# From: "Tunde  Dosumu" <barrister_td@lycos.com>
# From: MR TEMI JOHNSON <temijohnson2@rediffmail.com>
# From: "Dr.Sam jordan" <sjordan@diplomats.com>
# From: p_brown2@lawyer.com
# From: Barrister Peter Brown
# From: mic_k1@post.com
# From: "COL. MICHAEL BUNDU" <mikebunduu1@rediffmail.com>
# From: "MRS MARIAM ABACHA" <elixwilliam@usa.com>
# From: " DR. ANAYO AWKA " <anayoawka@hotmail.com>
# From: " DR. ANAYO AWKA " <anayoawka@hotmail.com>
# From: "Victor Aloma" <victorloma@netscape.net>
# ...

# %%
ownText="from saurabh to \nPriya"
re.findall("from .*",ownText)
# Out:
# ['from saurabh to ']

# %%
for line in re.findall("From:..............",emails):
    print(line)
# Out:
# From: "MR. JAMES NG
# From: "Mr. Ben Sule
# From: "PRINCE OBONG
# From: "PRINCE OBONG
# From: "Maryam Abach
# From: Kuta David <d
# From: "Barrister tu
# From: "William Dral
# From: "MR USMAN ABD
# From: "Tunde  Dosum
# From: MR TEMI JOHNS
# From: "Dr.Sam jorda
# From: p_brown2@lawy
# From: Barrister Pet
# From: mic_k1@post.c
# From: "COL. MICHAEL
# From: "MRS MARIAM A
# From: " DR. ANAYO A
# From: " DR. ANAYO A
# From: "Victor Aloma
# From: "Victor Aloma
# From: "JAMES NGOLA"
# From: "MARTIN CHIME
# From: "Mr George Mb
# From: "MARTIN  CHIM
# From: "MARTIN  CHIM
# From: <edema_mb@pha
# From: <edema_mb@pha
# From: "ADE WILLIAMS
# From: smithkam2@pos
# From: "MRS. M SESE-
# From: "obina okoro"
# From: "DR. JAMES  A
# From: software-semi
# From: adamuohiroma
# From: "MR FRED OBI.
# From: "mbeki ngumen
# From: mahoyi mamudu
# From: "Mr. David Ag
# From: "bell.idr bel
# From: "idris.bello
# From: john2002@blue
# From: "CLEMENT APUT
# From: "MR GODWIN IG
# From: "bell.idr bel
# ...

# %%
match = re.findall("From:.*", emails)

for line in match:
    print(re.findall("wS*@.*w", line))
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ...

# %%
emails[:1000]
# Out:
# 'From r  Wed Oct 30 21:41:56 2002\nReturn-Path: <james_ngola2002@maktoob.com>\nX-Sieve: cmu-sieve 2.0\nReturn-Path: <james_ngola2002@maktoob.com>\nMessage-Id: <200210310241.g9V2fNm6028281@cs.CU>\nFrom: "MR. JAMES NGOLA." <james_ngola2002@maktoob.com>\nReply-To: james_ngola2002@maktoob.com\nTo: webmaster@aclweb.org\nDate: Thu, 31 Oct 2002 02:38:20 +0000\nSubject: URGENT BUSINESS ASSISTANCE AND PARTNERSHIP\nX-Mailer: Microsoft Outlook Express 5.00.2919.6900 DM\nMIME-Version: 1.0\nContent-Type: text/plain; charset="us-ascii"\nContent-Transfer-Encoding: 8bit\nX-MIME-Autoconverted: from quoted-printable to 8bit by sideshowmel.si.UM id g9V2foW24311\nStatus: O\n\nFROM:MR. JAMES NGOLA.\nCONFIDENTIAL TEL: 233-27-587908.\nE-MAIL: (james_ngola2002@maktoob.com).\n\nURGENT BUSINESS ASSISTANCE AND PARTNERSHIP.\n\n\nDEAR FRIEND,\n\nI AM ( DR.) JAMES NGOLA, THE PERSONAL ASSISTANCE TO THE LATE CONGOLESE (PRESIDENT LAURENT KABILA) WHO WAS ASSASSINATED BY HIS BODY GUARD ON 16TH JAN. 2001.\n\n\nTHE INCI
# ...

# %%
address = re.findall("From:.*", emails)
for item in address:
    for line in re.findall("wS*@.*w", item):
        username, domain_name = re.split("@", line)
        print("{}, {}".format(username, domain_name))
# Out:
# w, w
# w, w
# w, terra.es" <markwwww

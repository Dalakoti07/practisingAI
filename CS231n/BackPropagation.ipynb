# %% [markdown]
# ![twelve.PNG](attachment:twelve.PNG)

# %% [markdown]
# ### Intutive sense of derivative

# %% [markdown]
# ![thirteen.PNG](attachment:thirteen.PNG)

# %% [markdown]
# ![14.PNG](attachment:14.PNG)

# %% [markdown]
# ![15.PNG](attachment:15.PNG)

# %%
# set some inputs
x = -2; y = 5; z = -4

# perform the forward pass
q = x + y # q becomes 3
f = q * z # f becomes -12

# perform the backward pass (backpropagation) in reverse order:
# first backprop through f = q * z
dfdz = q # df/dz = q, so gradient on z becomes 3
dfdq = z # df/dq = z, so gradient on q becomes -4
# now backprop through q = x + y
dfdx = 1.0 * dfdq # dq/dx = 1. And the multiplication here is the chain rule!
dfdy = 1.0 * dfdq # dq/dy = 1

# %% [markdown]
# ### Note that dfdx and dfdy are calculated with dfdq with help of chain rule

# %% [markdown]
# ![16.PNG](attachment:16.PNG)

# %% [markdown]
# # Intutive Understanding of Backward Propagation

# %% [markdown]
# ![17.PNG](attachment:17.PNG)

# %% [markdown]
# http://cs231n.stanford.edu/slides/2019/cs231n_2019_lecture04.pdf

# %% [markdown]
# ## Cannot make sense of Matrix grad

# %% [markdown]
# ![18.PNG](attachment:18.PNG)
